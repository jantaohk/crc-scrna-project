# %%
import scanpy as sc
import harmonypy as hm
import tqdm as notebook_tqdm
import phate
import pandas as pd
from matplotlib.colors import to_rgba
from pygam import LinearGAM, s
import meld
import scipy.stats as stats
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from itertools import combinations
import gseapy as gp
from scipy.stats import ttest_ind
from statannotations.Annotator import Annotator
import scprep

# %%
adata= sc.read_h5ad("/Users/Jan/data/final_final_data.h5ad")

# %%
# Figure 2B
sc.external.pl.phate(adata, color="Sample name", title= "Condition", frameon= False)

# %%
# Figure 2C
adata_wt= adata[adata.obs["Sample Type"]== "WT"]
sc.external.pl.phate(adata_wt, color="Sample name", title= "WT conditions", frameon= False)

# %%
# Figure 2D
adata_ka= adata[adata.obs["Sample Type"]== "KA"]
sc.external.pl.phate(adata_ka, color="Sample name", title= "KA conditions", frameon= False)
